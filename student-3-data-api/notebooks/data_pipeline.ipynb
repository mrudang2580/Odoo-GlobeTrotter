# %% [markdown]
# # GlobeTrotter Data Pipeline & EDA
# Exploring travel cities, cost index distributions, and activity categorizations.

# %%
import pandas as pd
cities_df = pd.read_csv('../data/cities.csv')
print(cities_df.head())
print('Average Cost Index:', cities_df['cost_index'].mean())
